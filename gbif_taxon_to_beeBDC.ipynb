# %%
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\mdw2685\\Desktop\\Projects\\early_tests\\Inverts_Taxon.csv')
# Out:
# C:\Users\mdw2685\AppData\Local\Temp\ipykernel_9180\894049766.py:1: DtypeWarning: Columns (6,7,8,9,10,13,16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\mdw2685\\Desktop\\Projects\\early_tests\\Inverts_Taxon.csv')

# %%
df.head()
# Out:
#    taxonID                             datasetID  parentNameUsageID  \
# 0  8987139  c8227bb4-4143-443f-8cb2-51f9576aff14                1.0
# 1        1  d7dddbf4-2cf0-4f39-9b2a-bb099caae36c                NaN
# 2  7961678  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
# 3  8137953  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
# 4  7758685  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
#
#    acceptedNameUsageID  originalNameUsageID  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
#
#                                    scientificName  \
# 0  Stipecrinus Villanueva-Olea & Sour-Tovar, 2014
# 1                                        Animalia
# 2                                      Liotheidae
# 3                                     Turbinoidae
# 4                                      Danaididae
#
#              scientificNameAuthorship canonicalName  genericName  \
# 0  Villanueva-Olea & Sour-Tovar, 2014   Stipecrinus  Stipecrinus
# 1                                 NaN      Animalia     Animalia
# 2                                 NaN    Liotheidae   Liotheidae
# 3                                 NaN   Turbinoidae  Turbinoidae
# 4                                 NaN    Danaididae   Danaididae
#
#   specificEpithet  ...                                    namePublishedIn  \
# 0             NaN  ...  Villanueva-Olea, Rafael & Francisco Sour-Tovar...
# 1             NaN  ...                                                NaN
# 2             NaN  ...           <i>Handb. Entomol.</i>, <b>2</b>(2): 436
# 3             NaN  ...                                                NaN
# 4             NaN  ...        <i>Acta Soc. Sci. fenn.</i>, <b>22</b>: 301
#
#   taxonomicStatus  nomenclaturalStatus taxonRemarks   kingdom  phylum class  \
# 0        accepted                  NaN          NaN  Animalia     NaN   NaN
# 1        accepted                  NaN          NaN  Animalia     NaN   NaN
# 2        accepted                  NaN          NaN  Animalia     NaN   NaN
# 3        accepted                  NaN          NaN  Animalia     NaN   NaN
# 4        accepted                  NaN          NaN  Animalia     NaN   NaN
#
#   order       family        genus
# 0   NaN          NaN  Stipecrinus
# 1   NaN          NaN          NaN
# 2   NaN   Liotheidae          NaN
# 3   NaN  Turbinoidae          NaN
# 4   NaN   Danaididae          NaN
#
# [5 rows x 23 columns]

# %%
df = df.rename(columns={'taxonID': 'id', 
                   'acceptedNameUsageID': 'accid', 
                   'taxonomicStatus': 'taxonomic_status', 
                   'canonicalName': 'canonical', 
                   'scientificName': 'validName',
                   'scientificNameAuthorship': 'authorship',
                   'taxonRank': 'taxon_rank',
                   'infraspecificEpithet': 'infraspecies',
                   }, errors="raise")

# %%
df['valid'] = np.where(df['taxonomicStatus'] == 'accepted', True, False)
df['source'] = 'gbif'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mdw2685\AppData\Local\miniconda3\envs\tpwd\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'taxonomicStatus'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df['valid'] = np.where(df['taxonomicStatus'] == 'accepted', True, False)
#       2 df['source'] = 'gbif'
#
# File c:\Users\mdw2685\AppData\Local\miniconda3\envs\tpwd\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\mdw2685\AppData\Local\miniconda3\envs\tpwd\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'taxonomicStatus'

# %%
df.head()
# Out:
#         id                             datasetID  parentNameUsageID  accid  \
# 0  8987139  c8227bb4-4143-443f-8cb2-51f9576aff14                1.0    NaN
# 1        1  d7dddbf4-2cf0-4f39-9b2a-bb099caae36c                NaN    NaN
# 2  7961678  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0    NaN
# 3  8137953  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0    NaN
# 4  7758685  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0    NaN
#
#    originalNameUsageID                                       validName  \
# 0                  NaN  Stipecrinus Villanueva-Olea & Sour-Tovar, 2014
# 1                  NaN                                        Animalia
# 2                  NaN                                      Liotheidae
# 3                  NaN                                     Turbinoidae
# 4                  NaN                                      Danaididae
#
#                            authorship    canonical  genericName  \
# 0  Villanueva-Olea & Sour-Tovar, 2014  Stipecrinus  Stipecrinus
# 1                                 NaN     Animalia     Animalia
# 2                                 NaN   Liotheidae   Liotheidae
# 3                                 NaN  Turbinoidae  Turbinoidae
# 4                                 NaN   Danaididae   Danaididae
#
#   specificEpithet  ... nomenclaturalStatus taxonRemarks   kingdom phylum  \
# 0             NaN  ...                 NaN          NaN  Animalia    NaN
# 1             NaN  ...                 NaN          NaN  Animalia    NaN
# 2             NaN  ...                 NaN          NaN  Animalia    NaN
# 3             NaN  ...                 NaN          NaN  Animalia    NaN
# 4             NaN  ...                 NaN          NaN  Animalia    NaN
#
#   class  order       family        genus valid source
# 0   NaN    NaN          NaN  Stipecrinus  True   gbif
# 1   NaN    NaN          NaN          NaN  True   gbif
# 2   NaN    NaN   Liotheidae          NaN  True   gbif
# 3   NaN    NaN  Turbinoidae          NaN  True   gbif
# 4   NaN    NaN   Danaididae          NaN  True   gbif
#
# [5 rows x 25 columns]

# %%
df.to_csv('C:\\Users\\mdw2685\\Desktop\\Projects\\early_tests\\corrected_inverts_taxon.csv', index=False)
