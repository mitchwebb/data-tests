# %%
import pandas as pd
import os

# %%
df = pd.read_csv('C:\\Users\\mdw2685\\Desktop\\Projects\\early_tests\\Inverts_Taxon.csv')
# Out:
# C:\Users\mdw2685\AppData\Local\Temp\ipykernel_23196\894049766.py:1: DtypeWarning: Columns (6,7,8,9,10,13,16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\mdw2685\\Desktop\\Projects\\early_tests\\Inverts_Taxon.csv')

# %%
df.head()
# Out:
#    taxonID                             datasetID  parentNameUsageID  \
# 0  8987139  c8227bb4-4143-443f-8cb2-51f9576aff14                1.0
# 1        1  d7dddbf4-2cf0-4f39-9b2a-bb099caae36c                NaN
# 2  7961678  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
# 3  8137953  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
# 4  7758685  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
#
#    acceptedNameUsageID  originalNameUsageID  \
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
#
#                                    scientificName  \
# 0  Stipecrinus Villanueva-Olea & Sour-Tovar, 2014
# 1                                        Animalia
# 2                                      Liotheidae
# 3                                     Turbinoidae
# ...

# %%
df.rename(columns={'taxonID': 'id', 
                   'acceptedNameUsageID': 'accid', 
                   'taxonomicStatus': 'taxonomic_status', 
                   'canonicalName': 'canonical', 
                   'scientificName': 'validName',
                   'scientificNameAuthorship': 'authorship',
                   'taxonRank': 'taxon_rank',
                   'infraspecificEpithet': 'infraspecies',
                   }, errors="raise")
# Out:
#                id                             datasetID  parentNameUsageID  \
# 0         8987139  c8227bb4-4143-443f-8cb2-51f9576aff14                1.0
# 1               1  d7dddbf4-2cf0-4f39-9b2a-bb099caae36c                NaN
# 2         7961678  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
# 3         8137953  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
# 4         7758685  80b4b440-eaca-4860-aadf-d0dfdd3e856e                1.0
# ...           ...                                   ...                ...
# 3978068  11346263  dbaa27eb-29e7-4cbb-8eab-3f689cfce116          1593713.0
# 3978069   1517849  7ddf754f-d193-4cc9-b351-99906754a03b          1517775.0
# 3978070   5970807  7ddf754f-d193-4cc9-b351-99906754a03b          2226678.0
# 3978071   2226679  7ddf754f-d193-4cc9-b351-99906754a03b          2226678.0
# 3978072   5970805  7ddf754f-d193-4cc9-b351-99906754a03b          2226678.0
#
#              accid  originalNameUsageID  \
# ...

# %%
df['valid'] = np.where(df['taxonomicStatus'] == 'accepted', True, False)
df['source'] = 'gbif'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23196\1346223735.py in ?()
# ----> 1 df['valid'] = True if df['taxonomicStatus'] == 'accepted' else False
#       2 df['source'] = 'gbif'
#
# c:\Users\mdw2685\AppData\Local\miniconda3\envs\tpwd\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
print(df['taxonomicStatus'])
# Out:
# 0          accepted
# 1          accepted
# 2          accepted
# 3          accepted
# 4          accepted
#              ...
# 3978068     synonym
# 3978069     synonym
# 3978070    accepted
# 3978071    accepted
# 3978072    accepted
# Name: taxonomicStatus, Length: 3978073, dtype: object
